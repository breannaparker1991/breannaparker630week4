# %%
#import libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
#imporiting csv into a dataframe
df = pd.read_csv("als_data.csv")

# %%
df
# Out:
#         ID  Age_mean  Albumin_max  Albumin_median  Albumin_min  Albumin_range  \
# 0        1        65         57.0            40.5         38.0       0.066202
# 1        2        48         45.0            41.0         39.0       0.010453
# 2        3        38         50.0            47.0         45.0       0.008929
# 3        4        63         47.0            44.0         41.0       0.012111
# 4        5        63         47.0            45.5         42.0       0.008292
# ...    ...       ...          ...             ...          ...            ...
# 2218  2419        33         50.0            49.0         45.0       0.008772
# 2219  2420        61         47.0            45.0         42.0       0.009074
# 2220  2421        47         46.0            44.0         41.0       0.012111
# 2221  2422        37         49.0            44.0         39.0       0.017857
# 2222  2424        48         48.0            45.0         40.0       0.018476
#
# ...

# %% [markdown]
# Remove any data that is not relevant to the patient’s ALS condition.

# %%
#removing the id column
df = df.drop('ID', axis=1)
df
# Out:
#       Age_mean  Albumin_max  Albumin_median  Albumin_min  Albumin_range  \
# 0           65         57.0            40.5         38.0       0.066202
# 1           48         45.0            41.0         39.0       0.010453
# 2           38         50.0            47.0         45.0       0.008929
# 3           63         47.0            44.0         41.0       0.012111
# 4           63         47.0            45.5         42.0       0.008292
# ...        ...          ...             ...          ...            ...
# 2218        33         50.0            49.0         45.0       0.008772
# 2219        61         47.0            45.0         42.0       0.009074
# 2220        47         46.0            44.0         41.0       0.012111
# 2221        37         49.0            44.0         39.0       0.017857
# 2222        48         48.0            45.0         40.0       0.018476
#
#       ALSFRS_slope  ALSFRS_Total_max  ALSFRS_Total_median  ALSFRS_Total_min  \
# ...

# %% [markdown]
# Apply a standard scalar to the data.

# %%
#assigning standarscaler
scaler = StandardScaler()

# %%
#fitting scaler
df_fit = scaler.fit_transform(df)
df_fit
# Out:
# array([[ 0.91713698,  3.08941722, -1.30078105, ..., -0.88037551,
#          0.46305355,  1.86853157],
#        [-0.57487867, -0.62201561, -1.11240084, ...,  0.1926645 ,
#         -1.13720768, -0.41915124],
#        [-1.45253494,  0.92441474,  1.14816173, ..., -0.88037551,
#         -1.13720768, -0.41915124],
#        ...,
#        [-0.6626443 , -0.31272954,  0.01788044, ...,  2.33874452,
#          0.46305355, -0.41915124],
#        [-1.54030057,  0.61512867,  0.01788044, ..., -0.88037551,
#         -1.13720768, -0.41915124],
#        [-0.57487867,  0.3058426 ,  0.39464087, ..., -1.95341552,
#         -1.13720768, -0.41915124]])

# %% [markdown]
# Create a plot of the cluster silhouette score versus the number of clusters in a K-means cluster.

# %%
#number of clusters
range_n_clusters = [2, 3, 4, 5, 6]

# %%
#empty list
silhouette_score = []

# %%
for cluster in range_n_clusters:
    
    # build k-means model
    kmeans = KMeans(n_clusters = cluster)
    kmeans.fit(df_fit)
    cluster_labels = kmeans.labels_
    
    # append the score into the empty list
    score.append(silhouette_score(df_fit, cluster_labels))
# Out:
# ----------------------------------------
# NameErrorTraceback (most recent call last)
# Cell In[18], line 4
#       1 for cluster in range_n_clusters:
#       2
#       3     # build k-means model
# ----> 4     kmeans = KMeans(n_clusters = cluster)
#       5     kmeans.fit(df_fit)
#       6     cluster_labels = kmeans.labels_
#
# NameError: name 'KMeans' is not defined

# %%
for num_clusters in range_n_clusters:
 
 # initialize k-means model
 kmeans = KMeans(n_clusters=num_clusters)
 kmeans.fit(df_fit)
 cluster_labels = kmeans.labels_
 
 # silhouette score
 silhouette_avg.append(silhouette_score(data_frame, cluster_labels))plt.plot(range_n_clusters,silhouette_avg,’bx-’)
plt.xlabel(‘Values of K’) 
plt.ylabel(‘Silhouette score’) 
plt.title(‘Silhouette analysis For Optimal k’)
plt.show()

# %%
# define a n number of clusters
n_number_clusters = [2, 3,4,5]

# intialize a empty list for adding all the score
score = []

for clustr in n_number_clusters:
    
    # build k-means model on different set of k values
    kmeans = KMeans(n_clusters = clustr)
    kmeans.fit(X)
    cluster_labels = kmeans.labels_
    
    # append the score into the empty list
    score.append(silhouette_score(X, cluster_labels))
    
# plot the graph    
plt.plot(n_number_clusters,score)
plt.show()

# %% [markdown]
# Use the plot created in (3) to choose on optimal number of clusters for K-means. Justify your choice.

# %% [markdown]
# Fit a K-means model to the data with the optimal number of clusters chosen in part (4).

# %% [markdown]
# Fit a PCA transformation with two features to the scaled data.

# %% [markdown]
# Make a scatterplot the PCA transformed data coloring each point by its cluster value.

# %% [markdown]
# Summarize your results and make a conclusion.
